# %%
import pandas as pd
import matplotlib.pyplot as plt

# the below dataframes contain the rim dice metric

df_Sorensen_Dice_rim  = pd.read_csv ('/Users/yamunasn/RR_AFNI_VNET/CNNouts/wt_out_128/dice128_rim_sorensen_dice/pro_128_Sorensen_Dice_rim.csv')
df_Sorensen_Dice_core  = pd.read_csv ('/Users/yamunasn/RR_AFNI_VNET/CNNouts/wt_out_128/dice128_rim_sorensen_dice/pro_128_Sorensen_Dice_core.csv')


df_six_point25_rim  = pd.read_csv ('/Users/yamunasn/RR_AFNI_VNET/CNNouts/wt_out_128/dice128_rim_sorensen_dice/pro128_six_point25_rim.csv')
df_six_point25_core  = pd.read_csv ('/Users/yamunasn/RR_AFNI_VNET/CNNouts/wt_out_128/dice128_rim_sorensen_dice/pro128_six_point25_core.csv')


df_twelve_point5_rim  = pd.read_csv ('/Users/yamunasn/RR_AFNI_VNET/CNNouts/wt_out_128/dice128_rim_sorensen_dice/pro128_twelve_point5_rim.csv')
df_twelve_point5_core  = pd.read_csv ('/Users/yamunasn/RR_AFNI_VNET/CNNouts/wt_out_128/dice128_rim_sorensen_dice/pro128_twelve_point5_core.csv')

# %%
df_Sorensen_Dice_rim['EPOCH_35'][10:15]
# Out:
# 10    0.863790
# 11    0.916488
# 12    0.916328
# 13    0.907637
# 14    0.894736
# Name: EPOCH_35, dtype: float64

# %%
fig = plt.figure(figsize=(10, 10))
boxplot = df_Sorensen_Dice_rim.boxplot(column=['EPOCH_0','EPOCH_10','EPOCH_20','EPOCH_30','EPOCH_50','EPOCH_70','EPOCH_80','EPOCH_90']
                                    ,grid=True, rot=45, fontsize=17)
plt.ylim(0.2,1.05)
plt.ylabel("Dice Coeffient",fontsize=17)
#plt.title("Mean Dice Coeffient of predicted masks across epochs for Sorensen_Dice_rim ",fontsize=17)
plt.title("df_Sorensen_Dice_rim ",fontsize=17)
fig.savefig("df_Sorensen_Dice_rim.jpg", format="jpg")

# %%
fig = plt.figure(figsize=(10, 10))
boxplot = df_Sorensen_Dice_core.boxplot(column=['EPOCH_0','EPOCH_10','EPOCH_20','EPOCH_30','EPOCH_50','EPOCH_70','EPOCH_80','EPOCH_90']
                                    ,grid=True, rot=45, fontsize=17)
plt.ylim(0.2,1.05)
plt.ylabel("Dice Coeffient",fontsize=17)
#plt.title("Mean Dice Coeffient of predicted masks across epochs for Sorensen_Dice_rim ",fontsize=17)
plt.title("df_Sorensen_Dice_core ",fontsize=17)
fig.savefig("df_Sorensen_Dice_core.jpg", format="jpg")

# %%
fig = plt.figure(figsize=(10, 10))
boxplot = df_six_point25_rim.boxplot(column=['EPOCH_0','EPOCH_10','EPOCH_20','EPOCH_30','EPOCH_50','EPOCH_70','EPOCH_80','EPOCH_90']
                                    ,grid=True, rot=45, fontsize=17)
plt.ylim(0.2,1.05)
plt.ylabel("Dice Coeffient",fontsize=17)
#plt.title("Mean Dice Coeffient of predicted masks across epochs for Sorensen_Dice_rim ",fontsize=17)
plt.title("df_six_point25_rim ",fontsize=17)
fig.savefig("df_six_point25_rim.jpg", format="jpg")

# %%
fig = plt.figure(figsize=(10, 10))
boxplot = df_six_point25_core.boxplot(column=['EPOCH_0','EPOCH_10','EPOCH_20','EPOCH_30','EPOCH_50','EPOCH_70','EPOCH_80','EPOCH_90']
                                    ,grid=True, rot=45, fontsize=17)
plt.ylim(0.2,1.05)
plt.ylabel("Dice Coeffient",fontsize=17)
#plt.title("Mean Dice Coeffient of predicted masks across epochs for Sorensen_Dice_rim ",fontsize=17)
plt.title("df_six_point25_core ",fontsize=17)
fig.savefig("df_six_point25_core.jpg", format="jpg")

# %%
fig = plt.figure(figsize=(10, 10))
boxplot = df_twelve_point5_rim.boxplot(column=['EPOCH_0','EPOCH_10','EPOCH_20','EPOCH_30','EPOCH_50','EPOCH_70','EPOCH_80','EPOCH_90']
                                    ,grid=True, rot=45, fontsize=17)
plt.ylim(0.2,1.05)
plt.ylabel("Dice Coeffient",fontsize=17)
#plt.title("Mean Dice Coeffient of predicted masks across epochs for Sorensen_Dice_rim ",fontsize=17)
plt.title("df_twelve_point5_rim ",fontsize=17)
fig.savefig("df_twelve_point5_rim.jpg", format="jpg")

# %%
fig = plt.figure(figsize=(10, 10))
boxplot = df_twelve_point5_core.boxplot(column=['EPOCH_0','EPOCH_10','EPOCH_20','EPOCH_30','EPOCH_50','EPOCH_70','EPOCH_80','EPOCH_90']
                                    ,grid=True, rot=45, fontsize=17)
plt.ylim(0.2,1.05)
plt.ylabel("Dice Coeffient",fontsize=17)
#plt.title("Mean Dice Coeffient of predicted masks across epochs for Sorensen_Dice_rim ",fontsize=17)
plt.title("df_twelve_point5_core ",fontsize=17)
fig.savefig("df_twelve_point5_core.jpg", format="jpg")
